# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#cargar archivo desde seaborn 
df=pd.read_csv('Mexico_limpio.csv')
#eliminamos la columna unnamed 
df= df.drop(['Unnamed: 0'], axis=1)
df.head(5)
# Out:
#                            listing_url  \
# 0   https://www.airbnb.com/rooms/35797
# 1   https://www.airbnb.com/rooms/44616
# 2   https://www.airbnb.com/rooms/67703
# 3   https://www.airbnb.com/rooms/70644
# 4  https://www.airbnb.com/rooms/107078
#
#                                                name  \
# 0                                       Villa Dante
# 1                                      Condesa Haus
# 2                 2 bedroom apt. deco bldg, Condesa
# 3  Beautiful light Studio Coyoacan- full equipped !
# 4                                NEW  DESIGNER LOFT
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  Comfortably furnished, sunny, 2 bedroom apt., ...
# 3  COYOACAN designer studio quiet & safe! well eq...
# 4  Is the best ever place triple L <br />Location...
#
#                                neighborhood_overview  \
# 0  Santa Fe Mall, Interloma Park and the Lion Des...
# 1                        No se proporcionan detalles
# 2                        No se proporcionan detalles
# 3  Coyoacan is a beautiful neighborhood famous fo...
# 4  Is located in the best area of Mexico City, Po...
#
#                                          picture_url host_name  host_since  \
# 0  https://a0.muscache.com/pictures/f395ab78-1185...      Dici  2010-06-28
# 1  https://a0.muscache.com/pictures/251410/ec75fe...  Fernando  2010-08-09
# 2  https://a0.muscache.com/pictures/3281720/6f078...  Nicholas  2011-01-04
# 3  https://a0.muscache.com/pictures/f397d2da-d045...    Trisha  2010-08-24
# 4  https://a0.muscache.com/pictures/bd64f86d-4931...    Andrea  2011-04-27
#
#    host_response_time host_response_rate host_is_superhost  ...  \
# 0  a few days or more                 0%                 f  ...
# 1      within an hour               100%                 t  ...
# 2      within an hour                71%                 t  ...
# 3  within a few hours               100%                 t  ...
# 4      within an hour               100%                 t  ...
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                      5.00                  5.00                        5.00
# 1                      4.70                  4.87                        4.78
# 2                      4.75                  4.94                        4.92
# 3                      4.96                  4.96                        4.98
# 4                      5.00                  5.00                        4.73
#
#   review_scores_location review_scores_value calculated_host_listings_count  \
# 0                   4.80                4.70                            1.0
# 1                   4.98                4.48                            8.0
# 2                   4.98                4.91                            2.0
# 3                   4.96                4.92                            3.0
# 4                   4.91                4.82                            3.0
#
#   calculated_host_listings_count_entire_homes  \
# 0                                         1.0
# 1                                         4.0
# 2                                         2.0
# 3                                         2.0
# 4                                         3.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          1.0
# 2                                          0.0
# 3                                          1.0
# 4                                          0.0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                         0.0              1.70
# 1                                         0.0              0.41
# 2                                         0.0              0.31
# 3                                         0.0              0.83
# 4                                         0.0              0.11
#
# [5 rows x 50 columns]

# %%
f1=df.iloc[ :  , [8,9,10,13,14,20,24,25,28,40] ]
f1
# Out:
#       host_response_rate host_is_superhost host_identity_verified  \
# 0                     0%                 f                      t
# 1                   100%                 t                      t
# 2                    71%                 t                      t
# 3                   100%                 t                      t
# 4                   100%                 t                      t
# ...                  ...               ...                    ...
# 26577               100%                 t                      t
# 26578               100%                 f                      t
# 26579               100%                 f                      t
# 26580               100%                 f                      t
# 26581               100%                 t                      t
#
#                     property_type        room_type instant_bookable  \
# 0                    Entire villa  Entire home/apt                f
# 1                     Entire home  Entire home/apt                f
# 2              Entire rental unit  Entire home/apt                f
# 3              Entire rental unit  Entire home/apt                f
# 4                     Entire loft  Entire home/apt                f
# ...                           ...              ...              ...
# 26577  Private room in guesthouse     Private room                t
# 26578               Room in hotel     Private room                t
# 26579               Room in hotel     Private room                t
# 26580               Room in hotel     Private room                t
# 26581          Entire rental unit  Entire home/apt                t
#
#        accommodates  bathrooms   price  review_scores_cleanliness
# 0               2.0        1.0  1093.1                       5.00
# 1               2.9        1.0  1511.6                       4.70
# 2               4.0        1.0  2029.0                       4.75
# 3               2.0        1.0  1140.0                       4.96
# 4               2.0        1.5  1093.1                       5.00
# ...             ...        ...     ...                        ...
# 26577           4.0        1.0   488.0                       5.00
# 26578           2.0        1.0  1093.1                       5.00
# 26579           2.0        1.0  2700.0                       5.00
# 26580           2.0        1.0  2600.0                       5.00
# 26581           2.0        1.0  1353.0                       5.00
#
# [26582 rows x 10 columns]

# %%
#convertimos string a tipos numéricos
f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})

#from sklearn.preprocessing import LabelEncoder
#encoder = LabelEncoder()
#f1['property_type'] = encoder.fit_transform(f1['property_type'])
#f1['property_type'] = f1['property_type'].astype(float)

frecuencias = f1['property_type'].value_counts()
f1['property_type'] = f1['property_type'].map(frecuencias)


f1['host_response_rate'] = f1['host_response_rate'].astype(str).str.rstrip('%')
f1['host_response_rate'] = pd.to_numeric(f1['host_response_rate'], errors='coerce').fillna(0)

f1['room_type'] = f1['room_type'].map({
    'Entire home/apt': 1,
    'Private room': 2,
    'Shared room': 3,
    'Hotel room': 4
})

f1['price'] = f1['price'].astype(str).str.rstrip('$')
f1['price'] = pd.to_numeric(f1['price'], errors='coerce').fillna(0)
# Out:
# C:\Users\josse\AppData\Local\Temp\ipykernel_14964\2186184959.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\josse\AppData\Local\Temp\ipykernel_14964\2186184959.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\josse\AppData\Local\Temp\ipykernel_14964\2186184959.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
# C:\Users\josse\AppData\Local\Temp\ipykernel_14964\2186184959.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
# C:\Users\josse\AppData\Local\Temp\ipykernel_14964\2186184959.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})
# C:\Users\josse\AppData\Local\Temp\ipykernel_14964\2186184959.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})
# C:\Users\josse\AppData\Local\Temp\ipykernel_14964\2186184959.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['property_type'] = f1['property_type'].map(frecuencias)
# C:\Users\josse\AppData\Local\Temp\ipykernel_14964\2186184959.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_response_rate'] = f1['host_response_rate'].astype(str).str.rstrip('%')
# C:\Users\josse\AppData\Local\Temp\ipykernel_14964\2186184959.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_response_rate'] = pd.to_numeric(f1['host_response_rate'], errors='coerce').fillna(0)
# C:\Users\josse\AppData\Local\Temp\ipykernel_14964\2186184959.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['room_type'] = f1['room_type'].map({
# C:\Users\josse\AppData\Local\Temp\ipykernel_14964\2186184959.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['price'] = f1['price'].astype(str).str.rstrip('$')
# C:\Users\josse\AppData\Local\Temp\ipykernel_14964\2186184959.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['price'] = pd.to_numeric(f1['price'], errors='coerce').fillna(0)

# %%
#f2 = Shared room
f2= f1[(f1["room_type"] == 4)]

# %%
f2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 125 entries, 48 to 24911
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   host_response_rate         125 non-null    float64
#  1   host_is_superhost          125 non-null    int64
#  2   host_identity_verified     125 non-null    int64
#  3   property_type              125 non-null    int64
#  4   room_type                  125 non-null    int64
#  5   instant_bookable           125 non-null    int64
#  6   accommodates               125 non-null    float64
#  7   bathrooms                  125 non-null    float64
#  8   price                      125 non-null    float64
#  9   review_scores_cleanliness  125 non-null    float64
# dtypes: float64(5), int64(5)
# memory usage: 10.7 KB

# %%
#imprimimos el scatter plot entre la variable dependiente total e independiente (a)
#para observar el comportamiento en su dispersión 

from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='host_response_rate', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='host_is_superhost', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='host_identity_verified', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='property_type', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='room_type', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='instant_bookable', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='review_scores_cleanliness', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='accommodates', color='blue', data=f2)
sns.scatterplot(x='bathrooms', y='accommodates', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='accommodates'>

# %% [markdown]
# **DECLARACIÓN DE VARIABLES INDEPENDIENTES Y DEPENDIENTES**

# %%
#declaración de las variables independientes que se van a comparar con el precio 
Var_Indep= f2[['host_response_rate']]
Var_Indep2=f2[['host_is_superhost']]
Var_Indep3=f2[['room_type']]
Var_Indep4=f2[['host_identity_verified']]
Var_Indep5= f2[['property_type']]
Var_Indep6= f2[['instant_bookable']]
Var_Indep7= f2[['review_scores_cleanliness']]
#declaración de variable independiente para accommodates 
Var_Indep8= f2[['bathrooms']]

# %%
#variables independientes para la regresión lineal
Var_Dep= f2['price']
Var_Dep2= f2['accommodates']

# %% [markdown]
# **DEFINICIÓN DEL MODELO**

# %%
#se define model como función de regresión lineal 
from sklearn.linear_model import LinearRegression 
model=LinearRegression()
model2=LinearRegression()
model3=LinearRegression()
model4=LinearRegression()
model5=LinearRegression()
model6=LinearRegression()
model7=LinearRegression()
model8=LinearRegression()

# %%
#verficamos la función relacionada al modelo 
type(model)
type(model2)
type(model3)
type(model4)
type(model5)
type(model6)
type(model7)
type(model8)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#ajustamos el modelo con las variables antes declaradas
model.fit(X=Var_Indep, y=Var_Dep)
model2.fit(X=Var_Indep2, y=Var_Dep)
model3.fit(X=Var_Indep3, y=Var_Dep)
model4.fit(X=Var_Indep4, y=Var_Dep)
model5.fit(X=Var_Indep5, y=Var_Dep)
model6.fit(X=Var_Indep6, y=Var_Dep)
model7.fit(X=Var_Indep7, y=Var_Dep)
model8.fit(X=Var_Indep8, y=Var_Dep2)
# Out:
# LinearRegression()

# %% [markdown]
# **COEFICIENTES OBTENIDOS PARA NUESTROS MODELOS**

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-1.25944689]),
#  'rank_': 1,
#  'singular_': array([282.17370537]),
#  'intercept_': np.float64(1406.0327560523476)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model2.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_is_superhost'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([230.30584677]),
#  'rank_': 1,
#  'singular_': array([4.87934422]),
#  'intercept_': np.float64(1232.2129032258067)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model3.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['room_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(1291.1712000000002)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model4.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_identity_verified'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([111.74073529]),
#  'rank_': 1,
#  'singular_': array([5.21536192]),
#  'intercept_': np.float64(1215.1875000000002)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model5.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['property_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.00754159]),
#  'rank_': 1,
#  'singular_': array([2446.38105944]),
#  'intercept_': np.float64(1289.2953354675935)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model6.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['instant_bookable'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-162.07706735]),
#  'rank_': 1,
#  'singular_': array([4.33220498]),
#  'intercept_': np.float64(1423.4260869565219)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model7.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-72.04598667]),
#  'rank_': 1,
#  'singular_': array([1.66464074]),
#  'intercept_': np.float64(1646.1677129014315)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model8.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['bathrooms'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([1.22337689]),
#  'rank_': 1,
#  'singular_': array([6.54702375]),
#  'intercept_': np.float64(1.3720183503361356)}

# %% [markdown]
# **A PARTIR DE AQUÍ PREDECIMOS VALORES DE ACUERDO AL MODELO MATEMÁTICO**

# %% [markdown]
# **Modelo matemático y=-0.94114872x + 1327.7330443080114**

# %%
#predecimos valores
y_pred= model.predict(X=f2[['host_response_rate']])
y_pred
# Out:
# array([1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1281.34751428, 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1332.98483663,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1406.03275605,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1281.34751428,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1406.03275605, 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1406.03275605, 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1406.03275605,
#        1406.03275605, 1280.0880674 , 1406.03275605, 1406.03275605,
#        1280.0880674 , 1280.0880674 , 1287.64474872, 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1343.06041173, 1343.06041173, 1343.06041173,
#        1343.06041173, 1343.06041173, 1343.06041173, 1343.06041173,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 , 1280.0880674 , 1280.0880674 , 1280.0880674 ,
#        1280.0880674 ])

# %% [markdown]
# **Modelo matemático y=21.00986237x + 1237.7516553524084**

# %%
#predecimos valores
y_pred2= model2.predict(X=f2[['host_is_superhost']])
y_pred2
# Out:
# array([1462.51875   , 1462.51875   , 1462.51875   , 1462.51875   ,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1462.51875   ,
#        1232.21290323, 1232.21290323, 1462.51875   , 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1462.51875   , 1462.51875   , 1462.51875   ,
#        1462.51875   , 1462.51875   , 1232.21290323, 1232.21290323,
#        1462.51875   , 1462.51875   , 1462.51875   , 1462.51875   ,
#        1462.51875   , 1462.51875   , 1462.51875   , 1462.51875   ,
#        1462.51875   , 1462.51875   , 1462.51875   , 1462.51875   ,
#        1462.51875   , 1232.21290323, 1462.51875   , 1462.51875   ,
#        1232.21290323, 1462.51875   , 1232.21290323, 1232.21290323,
#        1232.21290323, 1462.51875   , 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1462.51875   , 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1462.51875   , 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1462.51875   , 1462.51875   , 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323, 1232.21290323, 1232.21290323, 1232.21290323,
#        1232.21290323])

# %% [markdown]
# **Modelo matemático y=0x + 11247.1754189944133**

# %%
#predecimos valores
y_pred3= model3.predict(X=f2[['room_type']])
y_pred3
# Out:
# array([1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712])

# %% [markdown]
# **Modelo matemático y=-112.80942578x + 1357.171593533486**

# %%
#predecimos valores
y_pred4= model4.predict(X=f2[['host_identity_verified']])
y_pred4
# Out:
# array([1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1215.1875    , 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1215.1875    ,
#        1215.1875    , 1215.1875    , 1215.1875    , 1215.1875    ,
#        1215.1875    , 1215.1875    , 1215.1875    , 1215.1875    ,
#        1215.1875    , 1326.92823529, 1326.92823529, 1326.92823529,
#        1326.92823529, 1326.92823529, 1326.92823529, 1326.92823529,
#        1215.1875    , 1215.1875    , 1215.1875    , 1215.1875    ,
#        1215.1875    , 1215.1875    , 1215.1875    , 1215.1875    ,
#        1215.1875    , 1215.1875    , 1215.1875    , 1215.1875    ,
#        1215.1875    , 1215.1875    , 1215.1875    , 1215.1875    ,
#        1215.1875    , 1215.1875    , 1215.1875    , 1215.1875    ,
#        1215.1875    , 1215.1875    , 1215.1875    , 1215.1875    ,
#        1215.1875    , 1215.1875    , 1215.1875    , 1215.1875    ,
#        1215.1875    ])

# %% [markdown]
# **Modelo matemático y=-4.56100445x + 1325.0492572068565**

# %%
#predecimos valores
y_pred5= model5.predict(X=f2[['property_type']])
y_pred5
# Out:
# array([1289.51404153, 1290.60757185, 1290.60757185, 1289.51404153,
#        1289.51404153, 1289.51404153, 1289.51404153, 1289.51404153,
#        1289.51404153, 1289.40845929, 1289.51404153, 1289.51404153,
#        1289.40845929, 1289.51404153, 1289.51404153, 1289.80816348,
#        1290.60757185, 1289.51404153, 1289.51404153, 1289.51404153,
#        1289.80816348, 1289.51404153, 1289.51404153, 1289.51404153,
#        1289.51404153, 1289.51404153, 1290.60757185, 1289.51404153,
#        1289.51404153, 1293.09629602, 1293.09629602, 1293.09629602,
#        1293.09629602, 1293.09629602, 1293.09629602, 1293.09629602,
#        1293.09629602, 1293.09629602, 1293.09629602, 1293.09629602,
#        1293.09629602, 1289.40845929, 1290.60757185, 1289.51404153,
#        1290.60757185, 1289.51404153, 1289.51404153, 1289.51404153,
#        1289.51404153, 1290.60757185, 1289.40845929, 1290.60757185,
#        1289.31796023, 1289.40845929, 1289.51404153, 1289.51404153,
#        1289.40845929, 1289.40845929, 1289.40845929, 1289.40845929,
#        1289.40845929, 1290.60757185, 1290.60757185, 1290.60757185,
#        1290.60757185, 1290.60757185, 1289.40845929, 1289.40845929,
#        1289.31796023, 1289.40845929, 1289.40845929, 1289.51404153,
#        1290.60757185, 1289.40845929, 1290.60757185, 1290.60757185,
#        1290.60757185, 1289.31796023, 1289.30287706, 1293.09629602,
#        1293.09629602, 1293.09629602, 1293.09629602, 1293.09629602,
#        1293.09629602, 1293.09629602, 1293.09629602, 1293.09629602,
#        1293.09629602, 1290.60757185, 1290.60757185, 1290.60757185,
#        1290.60757185, 1290.60757185, 1290.60757185, 1290.60757185,
#        1293.09629602, 1293.09629602, 1293.09629602, 1293.09629602,
#        1293.09629602, 1293.09629602, 1293.09629602, 1293.09629602,
#        1293.09629602, 1293.09629602, 1293.09629602, 1293.09629602,
#        1293.09629602, 1293.09629602, 1293.09629602, 1293.09629602,
#        1293.09629602, 1293.09629602, 1293.09629602, 1293.09629602,
#        1293.09629602, 1293.09629602, 1293.09629602, 1293.09629602,
#        1293.09629602, 1293.09629602, 1293.09629602, 1293.09629602,
#        1293.09629602])

# %% [markdown]
# **Modelo matemático y=71.48464608x + 1217.0755372065255**

# %%
#predecimos valores
y_pred6= model6.predict(X=f2[['instant_bookable']])
y_pred6
# Out:
# array([1261.34901961, 1423.42608696, 1423.42608696, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1423.42608696, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1423.42608696, 1423.42608696, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1423.42608696, 1423.42608696, 1261.34901961,
#        1423.42608696, 1423.42608696, 1261.34901961, 1423.42608696,
#        1423.42608696, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1423.42608696, 1261.34901961, 1423.42608696,
#        1261.34901961, 1423.42608696, 1261.34901961, 1261.34901961,
#        1423.42608696, 1423.42608696, 1261.34901961, 1423.42608696,
#        1423.42608696, 1261.34901961, 1261.34901961, 1423.42608696,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1423.42608696,
#        1423.42608696, 1261.34901961, 1423.42608696, 1423.42608696,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961, 1261.34901961, 1261.34901961, 1261.34901961,
#        1261.34901961])

# %% [markdown]
# **Modelo matemático y=381.28956491x + -604.4218714343112**

# %%
y_pred7= model7.predict(X=f2[['review_scores_cleanliness']])
y_pred7
# Out:
# array([1285.93777953, 1285.93777953, 1288.09915913, 1285.93777953,
#        1297.4651374 , 1290.26053873, 1295.3037578 , 1288.09915913,
#        1285.93777953, 1293.1423782 , 1290.9809986 , 1294.58329793,
#        1285.93777953, 1285.93777953, 1293.1423782 , 1311.87433473,
#        1306.83111566, 1285.93777953, 1292.42191833, 1285.93777953,
#        1300.34697686, 1292.42191833, 1285.93777953, 1316.9175538 ,
#        1311.15387486, 1298.90605713, 1293.1423782 , 1290.9809986 ,
#        1293.86283806, 1321.96077287, 1321.96077287, 1285.93777953,
#        1285.93777953, 1285.93777953, 1327.00399193, 1326.28353207,
#        1316.9175538 , 1327.00399193, 1293.1423782 , 1293.1423782 ,
#        1307.55157553, 1321.240313  , 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1304.66973606, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1289.54007886, 1290.9809986 , 1285.93777953,
#        1293.1423782 , 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1309.71295513, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1329.16537153, 1285.93777953, 1285.93777953,
#        1285.93777953, 1313.31525446, 1293.1423782 , 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
#        1285.93777953])

# %% [markdown]
# **Modelo matemático y=0.97488088x + 2.1063441944025767**

# %%
y_pred8= model8.predict(X=f2[['bathrooms']])
y_pred8
# Out:
# array([2.59539525, 2.59539525, 2.59539525, 2.59539525, 2.59539525,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 2.96240831,
#        2.59539525, 3.81877214, 2.96240831, 2.96240831, 2.59539525,
#        2.59539525, 2.59539525, 2.96240831, 2.59539525, 2.59539525,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 2.59539525,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 2.59539525,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 2.59539525,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 2.59539525,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 2.59539525,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 3.20708369,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 2.59539525,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 3.20708369,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 2.59539525,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 2.59539525,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 2.59539525,
#        2.59539525, 2.59539525, 2.59539525, 2.59539525, 3.81877214,
#        3.81877214, 5.04214903, 2.59539525, 5.04214903, 5.04214903,
#        2.59539525, 2.59539525, 3.81877214, 3.81877214, 2.59539525,
#        2.59539525, 3.81877214, 5.04214903, 2.96240831, 2.59539525,
#        2.59539525, 3.81877214, 3.81877214, 3.81877214, 5.04214903,
#        2.96240831, 2.59539525, 2.59539525, 2.59539525, 2.59539525,
#        2.59539525, 2.59539525, 5.04214903, 5.04214903, 2.96240831,
#        2.96240831, 2.96240831, 2.59539525, 2.59539525, 3.81877214,
#        3.81877214, 3.81877214, 5.04214903, 5.04214903, 5.04214903,
#        2.96240831, 2.96240831, 2.96240831, 2.59539525, 2.59539525])

# %% [markdown]
# **INSERTAMOS LA COLUMNA DE PREDICCIONES A NUESTRO DATAFRAME**

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(0, 'Prediccion_host_response_rate', y_pred)
f2
# Out:
#        Prediccion_host_response_rate  host_response_rate  host_is_superhost  \
# 48                       1280.088067               100.0                  1
# 62                       1280.088067               100.0                  1
# 75                       1280.088067               100.0                  1
# 100                      1280.088067               100.0                  1
# 135                      1280.088067               100.0                  0
# ...                              ...                 ...                ...
# 24907                    1280.088067               100.0                  0
# 24908                    1280.088067               100.0                  0
# 24909                    1280.088067               100.0                  0
# 24910                    1280.088067               100.0                  0
# 24911                    1280.088067               100.0                  0
#
#        host_identity_verified  property_type  room_type  instant_bookable  \
# 48                          1             29          4                 1
# 62                          1            174          4                 0
# 75                          1            174          4                 0
# 100                         1             29          4                 1
# 135                         1             29          4                 1
# ...                       ...            ...        ...               ...
# 24907                       0            504          4                 1
# 24908                       0            504          4                 1
# 24909                       0            504          4                 1
# 24910                       0            504          4                 1
# 24911                       0            504          4                 1
#
#        accommodates  bathrooms   price  review_scores_cleanliness
# 48              3.0        1.0  1511.6                       5.00
# 62              2.0        1.0  1511.6                       5.00
# 75              2.0        1.0  1511.6                       4.97
# 100             3.0        1.0  1872.0                       5.00
# 135             2.0        1.0  1275.0                       4.84
# ...             ...        ...     ...                        ...
# 24907           2.9        1.3  1093.1                       5.00
# 24908           2.9        1.3  1093.1                       5.00
# 24909           2.9        1.3  1093.1                       5.00
# 24910           2.0        1.0  1484.0                       5.00
# 24911           3.0        1.0  1484.0                       5.00
#
# [125 rows x 11 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(1, 'Prediccion_host_is_superhost', y_pred2)
f2
# Out:
#        Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 48                       1280.088067                   1462.518750
# 62                       1280.088067                   1462.518750
# 75                       1280.088067                   1462.518750
# 100                      1280.088067                   1462.518750
# 135                      1280.088067                   1232.212903
# ...                              ...                           ...
# 24907                    1280.088067                   1232.212903
# 24908                    1280.088067                   1232.212903
# 24909                    1280.088067                   1232.212903
# 24910                    1280.088067                   1232.212903
# 24911                    1280.088067                   1232.212903
#
#        host_response_rate  host_is_superhost  host_identity_verified  \
# 48                  100.0                  1                       1
# 62                  100.0                  1                       1
# 75                  100.0                  1                       1
# 100                 100.0                  1                       1
# 135                 100.0                  0                       1
# ...                   ...                ...                     ...
# 24907               100.0                  0                       0
# 24908               100.0                  0                       0
# 24909               100.0                  0                       0
# 24910               100.0                  0                       0
# 24911               100.0                  0                       0
#
#        property_type  room_type  instant_bookable  accommodates  bathrooms  \
# 48                29          4                 1           3.0        1.0
# 62               174          4                 0           2.0        1.0
# 75               174          4                 0           2.0        1.0
# 100               29          4                 1           3.0        1.0
# 135               29          4                 1           2.0        1.0
# ...              ...        ...               ...           ...        ...
# 24907            504          4                 1           2.9        1.3
# 24908            504          4                 1           2.9        1.3
# 24909            504          4                 1           2.9        1.3
# 24910            504          4                 1           2.0        1.0
# 24911            504          4                 1           3.0        1.0
#
#         price  review_scores_cleanliness
# 48     1511.6                       5.00
# 62     1511.6                       5.00
# 75     1511.6                       4.97
# 100    1872.0                       5.00
# 135    1275.0                       4.84
# ...       ...                        ...
# 24907  1093.1                       5.00
# 24908  1093.1                       5.00
# 24909  1093.1                       5.00
# 24910  1484.0                       5.00
# 24911  1484.0                       5.00
#
# [125 rows x 12 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(2, 'Prediccion_room_type', y_pred3)
f2
# Out:
#        Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 48                       1280.088067                   1462.518750
# 62                       1280.088067                   1462.518750
# 75                       1280.088067                   1462.518750
# 100                      1280.088067                   1462.518750
# 135                      1280.088067                   1232.212903
# ...                              ...                           ...
# 24907                    1280.088067                   1232.212903
# 24908                    1280.088067                   1232.212903
# 24909                    1280.088067                   1232.212903
# 24910                    1280.088067                   1232.212903
# 24911                    1280.088067                   1232.212903
#
#        Prediccion_room_type  host_response_rate  host_is_superhost  \
# 48                1291.1712               100.0                  1
# 62                1291.1712               100.0                  1
# 75                1291.1712               100.0                  1
# 100               1291.1712               100.0                  1
# 135               1291.1712               100.0                  0
# ...                     ...                 ...                ...
# 24907             1291.1712               100.0                  0
# 24908             1291.1712               100.0                  0
# 24909             1291.1712               100.0                  0
# 24910             1291.1712               100.0                  0
# 24911             1291.1712               100.0                  0
#
#        host_identity_verified  property_type  room_type  instant_bookable  \
# 48                          1             29          4                 1
# 62                          1            174          4                 0
# 75                          1            174          4                 0
# 100                         1             29          4                 1
# 135                         1             29          4                 1
# ...                       ...            ...        ...               ...
# 24907                       0            504          4                 1
# 24908                       0            504          4                 1
# 24909                       0            504          4                 1
# 24910                       0            504          4                 1
# 24911                       0            504          4                 1
#
#        accommodates  bathrooms   price  review_scores_cleanliness
# 48              3.0        1.0  1511.6                       5.00
# 62              2.0        1.0  1511.6                       5.00
# 75              2.0        1.0  1511.6                       4.97
# 100             3.0        1.0  1872.0                       5.00
# 135             2.0        1.0  1275.0                       4.84
# ...             ...        ...     ...                        ...
# 24907           2.9        1.3  1093.1                       5.00
# 24908           2.9        1.3  1093.1                       5.00
# 24909           2.9        1.3  1093.1                       5.00
# 24910           2.0        1.0  1484.0                       5.00
# 24911           3.0        1.0  1484.0                       5.00
#
# [125 rows x 13 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(3, 'Prediccion_host_identity_verified', y_pred4)
f2
# Out:
#        Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 48                       1280.088067                   1462.518750
# 62                       1280.088067                   1462.518750
# 75                       1280.088067                   1462.518750
# 100                      1280.088067                   1462.518750
# 135                      1280.088067                   1232.212903
# ...                              ...                           ...
# 24907                    1280.088067                   1232.212903
# 24908                    1280.088067                   1232.212903
# 24909                    1280.088067                   1232.212903
# 24910                    1280.088067                   1232.212903
# 24911                    1280.088067                   1232.212903
#
#        Prediccion_room_type  Prediccion_host_identity_verified  \
# 48                1291.1712                        1326.928235
# 62                1291.1712                        1326.928235
# 75                1291.1712                        1326.928235
# 100               1291.1712                        1326.928235
# 135               1291.1712                        1326.928235
# ...                     ...                                ...
# 24907             1291.1712                        1215.187500
# 24908             1291.1712                        1215.187500
# 24909             1291.1712                        1215.187500
# 24910             1291.1712                        1215.187500
# 24911             1291.1712                        1215.187500
#
#        host_response_rate  host_is_superhost  host_identity_verified  \
# 48                  100.0                  1                       1
# 62                  100.0                  1                       1
# 75                  100.0                  1                       1
# 100                 100.0                  1                       1
# 135                 100.0                  0                       1
# ...                   ...                ...                     ...
# 24907               100.0                  0                       0
# 24908               100.0                  0                       0
# 24909               100.0                  0                       0
# 24910               100.0                  0                       0
# 24911               100.0                  0                       0
#
#        property_type  room_type  instant_bookable  accommodates  bathrooms  \
# 48                29          4                 1           3.0        1.0
# 62               174          4                 0           2.0        1.0
# 75               174          4                 0           2.0        1.0
# 100               29          4                 1           3.0        1.0
# 135               29          4                 1           2.0        1.0
# ...              ...        ...               ...           ...        ...
# 24907            504          4                 1           2.9        1.3
# 24908            504          4                 1           2.9        1.3
# 24909            504          4                 1           2.9        1.3
# 24910            504          4                 1           2.0        1.0
# 24911            504          4                 1           3.0        1.0
#
#         price  review_scores_cleanliness
# 48     1511.6                       5.00
# 62     1511.6                       5.00
# 75     1511.6                       4.97
# 100    1872.0                       5.00
# 135    1275.0                       4.84
# ...       ...                        ...
# 24907  1093.1                       5.00
# 24908  1093.1                       5.00
# 24909  1093.1                       5.00
# 24910  1484.0                       5.00
# 24911  1484.0                       5.00
#
# [125 rows x 14 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(4, 'Prediccion_property_type', y_pred5)
f2
# Out:
#        Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 48                       1280.088067                   1462.518750
# 62                       1280.088067                   1462.518750
# 75                       1280.088067                   1462.518750
# 100                      1280.088067                   1462.518750
# 135                      1280.088067                   1232.212903
# ...                              ...                           ...
# 24907                    1280.088067                   1232.212903
# 24908                    1280.088067                   1232.212903
# 24909                    1280.088067                   1232.212903
# 24910                    1280.088067                   1232.212903
# 24911                    1280.088067                   1232.212903
#
#        Prediccion_room_type  Prediccion_host_identity_verified  \
# 48                1291.1712                        1326.928235
# 62                1291.1712                        1326.928235
# 75                1291.1712                        1326.928235
# 100               1291.1712                        1326.928235
# 135               1291.1712                        1326.928235
# ...                     ...                                ...
# 24907             1291.1712                        1215.187500
# 24908             1291.1712                        1215.187500
# 24909             1291.1712                        1215.187500
# 24910             1291.1712                        1215.187500
# 24911             1291.1712                        1215.187500
#
#        Prediccion_property_type  host_response_rate  host_is_superhost  \
# 48                  1289.514042               100.0                  1
# 62                  1290.607572               100.0                  1
# 75                  1290.607572               100.0                  1
# 100                 1289.514042               100.0                  1
# 135                 1289.514042               100.0                  0
# ...                         ...                 ...                ...
# 24907               1293.096296               100.0                  0
# 24908               1293.096296               100.0                  0
# 24909               1293.096296               100.0                  0
# 24910               1293.096296               100.0                  0
# 24911               1293.096296               100.0                  0
#
#        host_identity_verified  property_type  room_type  instant_bookable  \
# 48                          1             29          4                 1
# 62                          1            174          4                 0
# 75                          1            174          4                 0
# 100                         1             29          4                 1
# 135                         1             29          4                 1
# ...                       ...            ...        ...               ...
# 24907                       0            504          4                 1
# 24908                       0            504          4                 1
# 24909                       0            504          4                 1
# 24910                       0            504          4                 1
# 24911                       0            504          4                 1
#
#        accommodates  bathrooms   price  review_scores_cleanliness
# 48              3.0        1.0  1511.6                       5.00
# 62              2.0        1.0  1511.6                       5.00
# 75              2.0        1.0  1511.6                       4.97
# 100             3.0        1.0  1872.0                       5.00
# 135             2.0        1.0  1275.0                       4.84
# ...             ...        ...     ...                        ...
# 24907           2.9        1.3  1093.1                       5.00
# 24908           2.9        1.3  1093.1                       5.00
# 24909           2.9        1.3  1093.1                       5.00
# 24910           2.0        1.0  1484.0                       5.00
# 24911           3.0        1.0  1484.0                       5.00
#
# [125 rows x 15 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(5, 'Prediccion_instant_bookable', y_pred6)
f2
# Out:
#        Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 48                       1280.088067                   1462.518750
# 62                       1280.088067                   1462.518750
# 75                       1280.088067                   1462.518750
# 100                      1280.088067                   1462.518750
# 135                      1280.088067                   1232.212903
# ...                              ...                           ...
# 24907                    1280.088067                   1232.212903
# 24908                    1280.088067                   1232.212903
# 24909                    1280.088067                   1232.212903
# 24910                    1280.088067                   1232.212903
# 24911                    1280.088067                   1232.212903
#
#        Prediccion_room_type  Prediccion_host_identity_verified  \
# 48                1291.1712                        1326.928235
# 62                1291.1712                        1326.928235
# 75                1291.1712                        1326.928235
# 100               1291.1712                        1326.928235
# 135               1291.1712                        1326.928235
# ...                     ...                                ...
# 24907             1291.1712                        1215.187500
# 24908             1291.1712                        1215.187500
# 24909             1291.1712                        1215.187500
# 24910             1291.1712                        1215.187500
# 24911             1291.1712                        1215.187500
#
#        Prediccion_property_type  Prediccion_instant_bookable  \
# 48                  1289.514042                  1261.349020
# 62                  1290.607572                  1423.426087
# 75                  1290.607572                  1423.426087
# 100                 1289.514042                  1261.349020
# 135                 1289.514042                  1261.349020
# ...                         ...                          ...
# 24907               1293.096296                  1261.349020
# 24908               1293.096296                  1261.349020
# 24909               1293.096296                  1261.349020
# 24910               1293.096296                  1261.349020
# 24911               1293.096296                  1261.349020
#
#        host_response_rate  host_is_superhost  host_identity_verified  \
# 48                  100.0                  1                       1
# 62                  100.0                  1                       1
# 75                  100.0                  1                       1
# 100                 100.0                  1                       1
# 135                 100.0                  0                       1
# ...                   ...                ...                     ...
# 24907               100.0                  0                       0
# 24908               100.0                  0                       0
# 24909               100.0                  0                       0
# 24910               100.0                  0                       0
# 24911               100.0                  0                       0
#
#        property_type  room_type  instant_bookable  accommodates  bathrooms  \
# 48                29          4                 1           3.0        1.0
# 62               174          4                 0           2.0        1.0
# 75               174          4                 0           2.0        1.0
# 100               29          4                 1           3.0        1.0
# 135               29          4                 1           2.0        1.0
# ...              ...        ...               ...           ...        ...
# 24907            504          4                 1           2.9        1.3
# 24908            504          4                 1           2.9        1.3
# 24909            504          4                 1           2.9        1.3
# 24910            504          4                 1           2.0        1.0
# 24911            504          4                 1           3.0        1.0
#
#         price  review_scores_cleanliness
# 48     1511.6                       5.00
# 62     1511.6                       5.00
# 75     1511.6                       4.97
# 100    1872.0                       5.00
# 135    1275.0                       4.84
# ...       ...                        ...
# 24907  1093.1                       5.00
# 24908  1093.1                       5.00
# 24909  1093.1                       5.00
# 24910  1484.0                       5.00
# 24911  1484.0                       5.00
#
# [125 rows x 16 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(6, 'Prediccion_review_scores_cleanliness', y_pred7)
f2
# Out:
#        Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 48                       1280.088067                   1462.518750
# 62                       1280.088067                   1462.518750
# 75                       1280.088067                   1462.518750
# 100                      1280.088067                   1462.518750
# 135                      1280.088067                   1232.212903
# ...                              ...                           ...
# 24907                    1280.088067                   1232.212903
# 24908                    1280.088067                   1232.212903
# 24909                    1280.088067                   1232.212903
# 24910                    1280.088067                   1232.212903
# 24911                    1280.088067                   1232.212903
#
#        Prediccion_room_type  Prediccion_host_identity_verified  \
# 48                1291.1712                        1326.928235
# 62                1291.1712                        1326.928235
# 75                1291.1712                        1326.928235
# 100               1291.1712                        1326.928235
# 135               1291.1712                        1326.928235
# ...                     ...                                ...
# 24907             1291.1712                        1215.187500
# 24908             1291.1712                        1215.187500
# 24909             1291.1712                        1215.187500
# 24910             1291.1712                        1215.187500
# 24911             1291.1712                        1215.187500
#
#        Prediccion_property_type  Prediccion_instant_bookable  \
# 48                  1289.514042                  1261.349020
# 62                  1290.607572                  1423.426087
# 75                  1290.607572                  1423.426087
# 100                 1289.514042                  1261.349020
# 135                 1289.514042                  1261.349020
# ...                         ...                          ...
# 24907               1293.096296                  1261.349020
# 24908               1293.096296                  1261.349020
# 24909               1293.096296                  1261.349020
# 24910               1293.096296                  1261.349020
# 24911               1293.096296                  1261.349020
#
#        Prediccion_review_scores_cleanliness  host_response_rate  \
# 48                              1285.937780               100.0
# 62                              1285.937780               100.0
# 75                              1288.099159               100.0
# 100                             1285.937780               100.0
# 135                             1297.465137               100.0
# ...                                     ...                 ...
# 24907                           1285.937780               100.0
# 24908                           1285.937780               100.0
# 24909                           1285.937780               100.0
# 24910                           1285.937780               100.0
# 24911                           1285.937780               100.0
#
#        host_is_superhost  host_identity_verified  property_type  room_type  \
# 48                     1                       1             29          4
# 62                     1                       1            174          4
# 75                     1                       1            174          4
# 100                    1                       1             29          4
# 135                    0                       1             29          4
# ...                  ...                     ...            ...        ...
# 24907                  0                       0            504          4
# 24908                  0                       0            504          4
# 24909                  0                       0            504          4
# 24910                  0                       0            504          4
# 24911                  0                       0            504          4
#
#        instant_bookable  accommodates  bathrooms   price  \
# 48                    1           3.0        1.0  1511.6
# 62                    0           2.0        1.0  1511.6
# 75                    0           2.0        1.0  1511.6
# 100                   1           3.0        1.0  1872.0
# 135                   1           2.0        1.0  1275.0
# ...                 ...           ...        ...     ...
# 24907                 1           2.9        1.3  1093.1
# 24908                 1           2.9        1.3  1093.1
# 24909                 1           2.9        1.3  1093.1
# 24910                 1           2.0        1.0  1484.0
# 24911                 1           3.0        1.0  1484.0
#
#        review_scores_cleanliness
# 48                          5.00
# 62                          5.00
# 75                          4.97
# 100                         5.00
# 135                         4.84
# ...                          ...
# 24907                       5.00
# 24908                       5.00
# 24909                       5.00
# 24910                       5.00
# 24911                       5.00
#
# [125 rows x 17 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(7, 'Prediccion_bathrooms', y_pred8)
f2
# Out:
#        Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 48                       1280.088067                   1462.518750
# 62                       1280.088067                   1462.518750
# 75                       1280.088067                   1462.518750
# 100                      1280.088067                   1462.518750
# 135                      1280.088067                   1232.212903
# ...                              ...                           ...
# 24907                    1280.088067                   1232.212903
# 24908                    1280.088067                   1232.212903
# 24909                    1280.088067                   1232.212903
# 24910                    1280.088067                   1232.212903
# 24911                    1280.088067                   1232.212903
#
#        Prediccion_room_type  Prediccion_host_identity_verified  \
# 48                1291.1712                        1326.928235
# 62                1291.1712                        1326.928235
# 75                1291.1712                        1326.928235
# 100               1291.1712                        1326.928235
# 135               1291.1712                        1326.928235
# ...                     ...                                ...
# 24907             1291.1712                        1215.187500
# 24908             1291.1712                        1215.187500
# 24909             1291.1712                        1215.187500
# 24910             1291.1712                        1215.187500
# 24911             1291.1712                        1215.187500
#
#        Prediccion_property_type  Prediccion_instant_bookable  \
# 48                  1289.514042                  1261.349020
# 62                  1290.607572                  1423.426087
# 75                  1290.607572                  1423.426087
# 100                 1289.514042                  1261.349020
# 135                 1289.514042                  1261.349020
# ...                         ...                          ...
# 24907               1293.096296                  1261.349020
# 24908               1293.096296                  1261.349020
# 24909               1293.096296                  1261.349020
# 24910               1293.096296                  1261.349020
# 24911               1293.096296                  1261.349020
#
#        Prediccion_review_scores_cleanliness  Prediccion_bathrooms  \
# 48                              1285.937780              2.595395
# 62                              1285.937780              2.595395
# 75                              1288.099159              2.595395
# 100                             1285.937780              2.595395
# 135                             1297.465137              2.595395
# ...                                     ...                   ...
# 24907                           1285.937780              2.962408
# 24908                           1285.937780              2.962408
# 24909                           1285.937780              2.962408
# 24910                           1285.937780              2.595395
# 24911                           1285.937780              2.595395
#
#        host_response_rate  host_is_superhost  host_identity_verified  \
# 48                  100.0                  1                       1
# 62                  100.0                  1                       1
# 75                  100.0                  1                       1
# 100                 100.0                  1                       1
# 135                 100.0                  0                       1
# ...                   ...                ...                     ...
# 24907               100.0                  0                       0
# 24908               100.0                  0                       0
# 24909               100.0                  0                       0
# 24910               100.0                  0                       0
# 24911               100.0                  0                       0
#
#        property_type  room_type  instant_bookable  accommodates  bathrooms  \
# 48                29          4                 1           3.0        1.0
# 62               174          4                 0           2.0        1.0
# 75               174          4                 0           2.0        1.0
# 100               29          4                 1           3.0        1.0
# 135               29          4                 1           2.0        1.0
# ...              ...        ...               ...           ...        ...
# 24907            504          4                 1           2.9        1.3
# 24908            504          4                 1           2.9        1.3
# 24909            504          4                 1           2.9        1.3
# 24910            504          4                 1           2.0        1.0
# 24911            504          4                 1           3.0        1.0
#
#         price  review_scores_cleanliness
# 48     1511.6                       5.00
# 62     1511.6                       5.00
# 75     1511.6                       4.97
# 100    1872.0                       5.00
# 135    1275.0                       4.84
# ...       ...                        ...
# 24907  1093.1                       5.00
# 24908  1093.1                       5.00
# 24909  1093.1                       5.00
# 24910  1484.0                       5.00
# 24911  1484.0                       5.00
#
# [125 rows x 18 columns]

# %% [markdown]
# **GRÁFICAS COMPARATIVAS**

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='host_response_rate', y='price', color='blue', data=f2)
sns.scatterplot(x='host_response_rate', y='Prediccion_host_response_rate', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='host_is_superhost', y='price', color='blue', data=f2)
sns.scatterplot(x='host_is_superhost', y='Prediccion_host_is_superhost', color='red', data=f2)
#sns.lineplot(x='host_is_superhost', y='Predicciones2', color='red', data=f2)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='room_type', y='Prediccion_room_type', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='host_identity_verified', y='price', color='blue', data=f2)
sns.scatterplot(x='host_identity_verified', y='Prediccion_host_identity_verified', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='property_type', y='price', color='blue', data=f2)
sns.scatterplot(x='property_type', y='Prediccion_property_type', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='instant_bookable', y='price', color='blue', data=f2)
sns.scatterplot(x='instant_bookable', y='Prediccion_instant_bookable', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='review_scores_cleanliness', y='price', color='blue', data=f2)
sns.scatterplot(x='review_scores_cleanliness', y='Prediccion_review_scores_cleanliness', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='bathrooms', y='accommodates', color='blue', data=f2)
sns.scatterplot(x='bathrooms', y='Prediccion_bathrooms', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %% [markdown]
# **COEFICIENTES DE DETERMINACIÓN**

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter= model.score(X=Var_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.00801614253904226

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter2= model2.score(X=Var_Indep2, y=Var_Dep)
coef_Deter2
# Out:
# 0.08015035963725525

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter3= model3.score(X=Var_Indep3, y=Var_Dep)
coef_Deter3
# Out:
# 0.0

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter4= model4.score(X=Var_Indep4, y=Var_Dep)
coef_Deter4
# Out:
# 0.02155582197416772

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter5= model5.score(X=Var_Indep5, y=Var_Dep)
coef_Deter5
# Out:
# 2.160461333322594e-05

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter6= model6.score(X=Var_Indep6, y=Var_Dep)
coef_Deter6
# Out:
# 0.03129203223743138

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter7= model7.score(X=Var_Indep7, y=Var_Dep)
coef_Deter7
# Out:
# 0.0009129211335544563

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter8= model8.score(X=Var_Indep8, y=Var_Dep2)
coef_Deter8
# Out:
# 0.29712134572686355

# %% [markdown]
# **COEFICIENTES DE CORRELACIÓN**

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.08953291316070454)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl2=np.sqrt(coef_Deter2)
coef_Correl2
# Out:
# np.float64(0.28310838849680037)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl3=np.sqrt(coef_Deter2)
coef_Correl3
# Out:
# np.float64(0.28310838849680037)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl4=np.sqrt(coef_Deter4)
coef_Correl4
# Out:
# np.float64(0.14681901094261507)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl5=np.sqrt(coef_Deter5)
coef_Correl5
# Out:
# np.float64(0.004648076304582999)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl6=np.sqrt(coef_Deter6)
coef_Correl6
# Out:
# np.float64(0.17689554046790262)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl7=np.sqrt(coef_Deter7)
coef_Correl7
# Out:
# np.float64(0.030214584782095818)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl8=np.sqrt(coef_Deter8)
coef_Correl8
# Out:
# np.float64(0.545088383408474)

# %%
#eliminamos room_type y su prediccion 

f2= f2.drop(['room_type', 'Prediccion_room_type' ], axis=1)

# %%
#Graficamos todas las dispersiones entre todas las variables
sns.pairplot(f2)

# %%
#Analizar categorias de una columna
df6 = f2.groupby(['host_response_rate'])['host_response_rate'].count()
df6
# Out:
# host_response_rate
# 0.0        7
# 50.0       7
# 58.0       1
# 94.0       1
# 99.0       2
# 100.0    107
# Name: host_response_rate, dtype: int64

# %%
#Encontramos todas las correlaciones entre las variables 
Corr_Factors= f2.corr()
Corr_Factors
# Out:
#                                       Prediccion_host_response_rate  \
# Prediccion_host_response_rate                              1.000000
# Prediccion_host_is_superhost                              -0.131898
# Prediccion_host_identity_verified                          0.171238
# Prediccion_property_type                                  -0.215252
# Prediccion_instant_bookable                                0.326071
# Prediccion_review_scores_cleanliness                      -0.136346
# Prediccion_bathrooms                                      -0.085028
# host_response_rate                                        -1.000000
# host_is_superhost                                         -0.131898
# host_identity_verified                                     0.171238
# property_type                                             -0.215252
# instant_bookable                                          -0.326071
# accommodates                                               0.006763
# bathrooms                                                 -0.085028
# price                                                      0.089533
# review_scores_cleanliness                                  0.136346
#
#                                       Prediccion_host_is_superhost  \
# Prediccion_host_response_rate                            -0.131898
# Prediccion_host_is_superhost                              1.000000
# Prediccion_host_identity_verified                         0.402396
# Prediccion_property_type                                 -0.055170
# Prediccion_instant_bookable                               0.241836
# Prediccion_review_scores_cleanliness                      0.421740
# Prediccion_bathrooms                                     -0.246347
# host_response_rate                                        0.131898
# host_is_superhost                                         1.000000
# host_identity_verified                                    0.402396
# property_type                                            -0.055170
# instant_bookable                                         -0.241836
# accommodates                                             -0.062976
# bathrooms                                                -0.246347
# price                                                     0.283108
# review_scores_cleanliness                                -0.421740
#
#                                       Prediccion_host_identity_verified  \
# Prediccion_host_response_rate                                  0.171238
# Prediccion_host_is_superhost                                   0.402396
# Prediccion_host_identity_verified                              1.000000
# Prediccion_property_type                                      -0.761011
# Prediccion_instant_bookable                                    0.281490
# Prediccion_review_scores_cleanliness                           0.334681
# Prediccion_bathrooms                                          -0.538525
# host_response_rate                                            -0.171238
# host_is_superhost                                              0.402396
# host_identity_verified                                         1.000000
# property_type                                                 -0.761011
# instant_bookable                                              -0.281490
# accommodates                                                  -0.350445
# bathrooms                                                     -0.538525
# price                                                          0.146819
# review_scores_cleanliness                                     -0.334681
#
#                                       Prediccion_property_type  \
# Prediccion_host_response_rate                        -0.215252
# Prediccion_host_is_superhost                         -0.055170
# Prediccion_host_identity_verified                    -0.761011
# Prediccion_property_type                              1.000000
# Prediccion_instant_bookable                          -0.384869
# Prediccion_review_scores_cleanliness                 -0.057179
# Prediccion_bathrooms                                  0.423985
# host_response_rate                                    0.215252
# host_is_superhost                                    -0.055170
# host_identity_verified                               -0.761011
# property_type                                         1.000000
# instant_bookable                                      0.384869
# accommodates                                          0.474374
# bathrooms                                             0.423985
# price                                                 0.004648
# review_scores_cleanliness                             0.057179
#
#                                       Prediccion_instant_bookable  \
# Prediccion_host_response_rate                            0.326071
# Prediccion_host_is_superhost                             0.241836
# Prediccion_host_identity_verified                        0.281490
# Prediccion_property_type                                -0.384869
# Prediccion_instant_bookable                              1.000000
# Prediccion_review_scores_cleanliness                    -0.034766
# Prediccion_bathrooms                                    -0.209230
# host_response_rate                                      -0.326071
# host_is_superhost                                        0.241836
# host_identity_verified                                   0.281490
# property_type                                           -0.384869
# instant_bookable                                        -1.000000
# accommodates                                            -0.222015
# bathrooms                                               -0.209230
# price                                                    0.176896
# review_scores_cleanliness                                0.034766
#
#                                       Prediccion_review_scores_cleanliness  \
# Prediccion_host_response_rate                                    -0.136346
# Prediccion_host_is_superhost                                      0.421740
# Prediccion_host_identity_verified                                 0.334681
# Prediccion_property_type                                         -0.057179
# Prediccion_instant_bookable                                      -0.034766
# Prediccion_review_scores_cleanliness                              1.000000
# Prediccion_bathrooms                                             -0.230182
# host_response_rate                                                0.136346
# host_is_superhost                                                 0.421740
# host_identity_verified                                            0.334681
# property_type                                                    -0.057179
# instant_bookable                                                  0.034766
# accommodates                                                     -0.024885
# bathrooms                                                        -0.230182
# price                                                             0.030215
# review_scores_cleanliness                                        -1.000000
#
#                                       Prediccion_bathrooms  \
# Prediccion_host_response_rate                    -0.085028
# Prediccion_host_is_superhost                     -0.246347
# Prediccion_host_identity_verified                -0.538525
# Prediccion_property_type                          0.423985
# Prediccion_instant_bookable                      -0.209230
# Prediccion_review_scores_cleanliness             -0.230182
# Prediccion_bathrooms                              1.000000
# host_response_rate                                0.085028
# host_is_superhost                                -0.246347
# host_identity_verified                           -0.538525
# property_type                                     0.423985
# instant_bookable                                  0.209230
# accommodates                                      0.545088
# bathrooms                                         1.000000
# price                                            -0.278962
# review_scores_cleanliness                         0.230182
#
#                                       host_response_rate  host_is_superhost  \
# Prediccion_host_response_rate                  -1.000000          -0.131898
# Prediccion_host_is_superhost                    0.131898           1.000000
# Prediccion_host_identity_verified              -0.171238           0.402396
# Prediccion_property_type                        0.215252          -0.055170
# Prediccion_instant_bookable                    -0.326071           0.241836
# Prediccion_review_scores_cleanliness            0.136346           0.421740
# Prediccion_bathrooms                            0.085028          -0.246347
# host_response_rate                              1.000000           0.131898
# host_is_superhost                               0.131898           1.000000
# host_identity_verified                         -0.171238           0.402396
# property_type                                   0.215252          -0.055170
# instant_bookable                                0.326071          -0.241836
# accommodates                                   -0.006763          -0.062976
# bathrooms                                       0.085028          -0.246347
# price                                          -0.089533           0.283108
# review_scores_cleanliness                      -0.136346          -0.421740
#
#                                       host_identity_verified  property_type  \
# Prediccion_host_response_rate                       0.171238      -0.215252
# Prediccion_host_is_superhost                        0.402396      -0.055170
# Prediccion_host_identity_verified                   1.000000      -0.761011
# Prediccion_property_type                           -0.761011       1.000000
# Prediccion_instant_bookable                         0.281490      -0.384869
# Prediccion_review_scores_cleanliness                0.334681      -0.057179
# Prediccion_bathrooms                               -0.538525       0.423985
# host_response_rate                                 -0.171238       0.215252
# host_is_superhost                                   0.402396      -0.055170
# host_identity_verified                              1.000000      -0.761011
# property_type                                      -0.761011       1.000000
# instant_bookable                                   -0.281490       0.384869
# accommodates                                       -0.350445       0.474374
# bathrooms                                          -0.538525       0.423985
# price                                               0.146819       0.004648
# review_scores_cleanliness                          -0.334681       0.057179
#
#                                       instant_bookable  accommodates  \
# Prediccion_host_response_rate                -0.326071      0.006763
# Prediccion_host_is_superhost                 -0.241836     -0.062976
# Prediccion_host_identity_verified            -0.281490     -0.350445
# Prediccion_property_type                      0.384869      0.474374
# Prediccion_instant_bookable                  -1.000000     -0.222015
# Prediccion_review_scores_cleanliness          0.034766     -0.024885
# Prediccion_bathrooms                          0.209230      0.545088
# host_response_rate                            0.326071     -0.006763
# host_is_superhost                            -0.241836     -0.062976
# host_identity_verified                       -0.281490     -0.350445
# property_type                                 0.384869      0.474374
# instant_bookable                              1.000000      0.222015
# accommodates                                  0.222015      1.000000
# bathrooms                                     0.209230      0.545088
# price                                        -0.176896      0.036598
# review_scores_cleanliness                    -0.034766      0.024885
#
#                                       bathrooms     price  \
# Prediccion_host_response_rate         -0.085028  0.089533
# Prediccion_host_is_superhost          -0.246347  0.283108
# Prediccion_host_identity_verified     -0.538525  0.146819
# Prediccion_property_type               0.423985  0.004648
# Prediccion_instant_bookable           -0.209230  0.176896
# Prediccion_review_scores_cleanliness  -0.230182  0.030215
# Prediccion_bathrooms                   1.000000 -0.278962
# host_response_rate                     0.085028 -0.089533
# host_is_superhost                     -0.246347  0.283108
# host_identity_verified                -0.538525  0.146819
# property_type                          0.423985  0.004648
# instant_bookable                       0.209230 -0.176896
# accommodates                           0.545088  0.036598
# bathrooms                              1.000000 -0.278962
# price                                 -0.278962  1.000000
# review_scores_cleanliness              0.230182 -0.030215
#
#                                       review_scores_cleanliness
# Prediccion_host_response_rate                          0.136346
# Prediccion_host_is_superhost                          -0.421740
# Prediccion_host_identity_verified                     -0.334681
# Prediccion_property_type                               0.057179
# Prediccion_instant_bookable                            0.034766
# Prediccion_review_scores_cleanliness                  -1.000000
# Prediccion_bathrooms                                   0.230182
# host_response_rate                                    -0.136346
# host_is_superhost                                     -0.421740
# host_identity_verified                                -0.334681
# property_type                                          0.057179
# instant_bookable                                      -0.034766
# accommodates                                           0.024885
# bathrooms                                              0.230182
# price                                                 -0.030215
# review_scores_cleanliness                              1.000000

# %%
#Encontramos el valor absoluto de todas las correlaciones entre las variables 
Corr_Factors1= abs(Corr_Factors)
Corr_Factors1
# Out:
#                                       Prediccion_host_response_rate  \
# Prediccion_host_response_rate                              1.000000
# Prediccion_host_is_superhost                               0.131898
# Prediccion_host_identity_verified                          0.171238
# Prediccion_property_type                                   0.215252
# Prediccion_instant_bookable                                0.326071
# Prediccion_review_scores_cleanliness                       0.136346
# Prediccion_bathrooms                                       0.085028
# host_response_rate                                         1.000000
# host_is_superhost                                          0.131898
# host_identity_verified                                     0.171238
# property_type                                              0.215252
# instant_bookable                                           0.326071
# accommodates                                               0.006763
# bathrooms                                                  0.085028
# price                                                      0.089533
# review_scores_cleanliness                                  0.136346
#
#                                       Prediccion_host_is_superhost  \
# Prediccion_host_response_rate                             0.131898
# Prediccion_host_is_superhost                              1.000000
# Prediccion_host_identity_verified                         0.402396
# Prediccion_property_type                                  0.055170
# Prediccion_instant_bookable                               0.241836
# Prediccion_review_scores_cleanliness                      0.421740
# Prediccion_bathrooms                                      0.246347
# host_response_rate                                        0.131898
# host_is_superhost                                         1.000000
# host_identity_verified                                    0.402396
# property_type                                             0.055170
# instant_bookable                                          0.241836
# accommodates                                              0.062976
# bathrooms                                                 0.246347
# price                                                     0.283108
# review_scores_cleanliness                                 0.421740
#
#                                       Prediccion_host_identity_verified  \
# Prediccion_host_response_rate                                  0.171238
# Prediccion_host_is_superhost                                   0.402396
# Prediccion_host_identity_verified                              1.000000
# Prediccion_property_type                                       0.761011
# Prediccion_instant_bookable                                    0.281490
# Prediccion_review_scores_cleanliness                           0.334681
# Prediccion_bathrooms                                           0.538525
# host_response_rate                                             0.171238
# host_is_superhost                                              0.402396
# host_identity_verified                                         1.000000
# property_type                                                  0.761011
# instant_bookable                                               0.281490
# accommodates                                                   0.350445
# bathrooms                                                      0.538525
# price                                                          0.146819
# review_scores_cleanliness                                      0.334681
#
#                                       Prediccion_property_type  \
# Prediccion_host_response_rate                         0.215252
# Prediccion_host_is_superhost                          0.055170
# Prediccion_host_identity_verified                     0.761011
# Prediccion_property_type                              1.000000
# Prediccion_instant_bookable                           0.384869
# Prediccion_review_scores_cleanliness                  0.057179
# Prediccion_bathrooms                                  0.423985
# host_response_rate                                    0.215252
# host_is_superhost                                     0.055170
# host_identity_verified                                0.761011
# property_type                                         1.000000
# instant_bookable                                      0.384869
# accommodates                                          0.474374
# bathrooms                                             0.423985
# price                                                 0.004648
# review_scores_cleanliness                             0.057179
#
#                                       Prediccion_instant_bookable  \
# Prediccion_host_response_rate                            0.326071
# Prediccion_host_is_superhost                             0.241836
# Prediccion_host_identity_verified                        0.281490
# Prediccion_property_type                                 0.384869
# Prediccion_instant_bookable                              1.000000
# Prediccion_review_scores_cleanliness                     0.034766
# Prediccion_bathrooms                                     0.209230
# host_response_rate                                       0.326071
# host_is_superhost                                        0.241836
# host_identity_verified                                   0.281490
# property_type                                            0.384869
# instant_bookable                                         1.000000
# accommodates                                             0.222015
# bathrooms                                                0.209230
# price                                                    0.176896
# review_scores_cleanliness                                0.034766
#
#                                       Prediccion_review_scores_cleanliness  \
# Prediccion_host_response_rate                                     0.136346
# Prediccion_host_is_superhost                                      0.421740
# Prediccion_host_identity_verified                                 0.334681
# Prediccion_property_type                                          0.057179
# Prediccion_instant_bookable                                       0.034766
# Prediccion_review_scores_cleanliness                              1.000000
# Prediccion_bathrooms                                              0.230182
# host_response_rate                                                0.136346
# host_is_superhost                                                 0.421740
# host_identity_verified                                            0.334681
# property_type                                                     0.057179
# instant_bookable                                                  0.034766
# accommodates                                                      0.024885
# bathrooms                                                         0.230182
# price                                                             0.030215
# review_scores_cleanliness                                         1.000000
#
#                                       Prediccion_bathrooms  \
# Prediccion_host_response_rate                     0.085028
# Prediccion_host_is_superhost                      0.246347
# Prediccion_host_identity_verified                 0.538525
# Prediccion_property_type                          0.423985
# Prediccion_instant_bookable                       0.209230
# Prediccion_review_scores_cleanliness              0.230182
# Prediccion_bathrooms                              1.000000
# host_response_rate                                0.085028
# host_is_superhost                                 0.246347
# host_identity_verified                            0.538525
# property_type                                     0.423985
# instant_bookable                                  0.209230
# accommodates                                      0.545088
# bathrooms                                         1.000000
# price                                             0.278962
# review_scores_cleanliness                         0.230182
#
#                                       host_response_rate  host_is_superhost  \
# Prediccion_host_response_rate                   1.000000           0.131898
# Prediccion_host_is_superhost                    0.131898           1.000000
# Prediccion_host_identity_verified               0.171238           0.402396
# Prediccion_property_type                        0.215252           0.055170
# Prediccion_instant_bookable                     0.326071           0.241836
# Prediccion_review_scores_cleanliness            0.136346           0.421740
# Prediccion_bathrooms                            0.085028           0.246347
# host_response_rate                              1.000000           0.131898
# host_is_superhost                               0.131898           1.000000
# host_identity_verified                          0.171238           0.402396
# property_type                                   0.215252           0.055170
# instant_bookable                                0.326071           0.241836
# accommodates                                    0.006763           0.062976
# bathrooms                                       0.085028           0.246347
# price                                           0.089533           0.283108
# review_scores_cleanliness                       0.136346           0.421740
#
#                                       host_identity_verified  property_type  \
# Prediccion_host_response_rate                       0.171238       0.215252
# Prediccion_host_is_superhost                        0.402396       0.055170
# Prediccion_host_identity_verified                   1.000000       0.761011
# Prediccion_property_type                            0.761011       1.000000
# Prediccion_instant_bookable                         0.281490       0.384869
# Prediccion_review_scores_cleanliness                0.334681       0.057179
# Prediccion_bathrooms                                0.538525       0.423985
# host_response_rate                                  0.171238       0.215252
# host_is_superhost                                   0.402396       0.055170
# host_identity_verified                              1.000000       0.761011
# property_type                                       0.761011       1.000000
# instant_bookable                                    0.281490       0.384869
# accommodates                                        0.350445       0.474374
# bathrooms                                           0.538525       0.423985
# price                                               0.146819       0.004648
# review_scores_cleanliness                           0.334681       0.057179
#
#                                       instant_bookable  accommodates  \
# Prediccion_host_response_rate                 0.326071      0.006763
# Prediccion_host_is_superhost                  0.241836      0.062976
# Prediccion_host_identity_verified             0.281490      0.350445
# Prediccion_property_type                      0.384869      0.474374
# Prediccion_instant_bookable                   1.000000      0.222015
# Prediccion_review_scores_cleanliness          0.034766      0.024885
# Prediccion_bathrooms                          0.209230      0.545088
# host_response_rate                            0.326071      0.006763
# host_is_superhost                             0.241836      0.062976
# host_identity_verified                        0.281490      0.350445
# property_type                                 0.384869      0.474374
# instant_bookable                              1.000000      0.222015
# accommodates                                  0.222015      1.000000
# bathrooms                                     0.209230      0.545088
# price                                         0.176896      0.036598
# review_scores_cleanliness                     0.034766      0.024885
#
#                                       bathrooms     price  \
# Prediccion_host_response_rate          0.085028  0.089533
# Prediccion_host_is_superhost           0.246347  0.283108
# Prediccion_host_identity_verified      0.538525  0.146819
# Prediccion_property_type               0.423985  0.004648
# Prediccion_instant_bookable            0.209230  0.176896
# Prediccion_review_scores_cleanliness   0.230182  0.030215
# Prediccion_bathrooms                   1.000000  0.278962
# host_response_rate                     0.085028  0.089533
# host_is_superhost                      0.246347  0.283108
# host_identity_verified                 0.538525  0.146819
# property_type                          0.423985  0.004648
# instant_bookable                       0.209230  0.176896
# accommodates                           0.545088  0.036598
# bathrooms                              1.000000  0.278962
# price                                  0.278962  1.000000
# review_scores_cleanliness              0.230182  0.030215
#
#                                       review_scores_cleanliness
# Prediccion_host_response_rate                          0.136346
# Prediccion_host_is_superhost                           0.421740
# Prediccion_host_identity_verified                      0.334681
# Prediccion_property_type                               0.057179
# Prediccion_instant_bookable                            0.034766
# Prediccion_review_scores_cleanliness                   1.000000
# Prediccion_bathrooms                                   0.230182
# host_response_rate                                     0.136346
# host_is_superhost                                      0.421740
# host_identity_verified                                 0.334681
# property_type                                          0.057179
# instant_bookable                                       0.034766
# accommodates                                           0.024885
# bathrooms                                              0.230182
# price                                                  0.030215
# review_scores_cleanliness                              1.000000

# %%
#Graficamos el mapa de calor de las coeficientes de correlación 
Heart_Nap = sns.heatmap(Corr_Factors1, cmap= 'coolwarm')
Heart_Nap
# Out:
# <Axes: >

# %%
#Ajustamos el mapa de calor de las coeficientes de correlación 
plt.figure(figsize=(12,8))
Heart_Nap = sns.heatmap(Corr_Factors1, cmap= 'Purples', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >

# %%
# Obtener R² de cada modelo
r2_1 = model.score(Var_Indep, Var_Dep)
r2_2 = model2.score(Var_Indep2, Var_Dep)
r2_3 = model3.score(Var_Indep3, Var_Dep)
r2_4 = model4.score(Var_Indep4, Var_Dep)
r2_5 = model5.score(Var_Indep5, Var_Dep)
r2_6 = model6.score(Var_Indep6, Var_Dep)
r2_7 = model7.score(Var_Indep7, Var_Dep)
r2_8 = model8.score(Var_Indep8, Var_Dep2)

# Guardar los resultados en un diccionario
r2_values = {
    "host_response_rate": r2_1,
    "host_is_superhost": r2_2,
    "room_type": r2_3,
    "host_identity_verified": r2_4,
    "property_type": r2_5,
    "instant_bookable": r2_6,
    "review_scores_cleanliness": r2_7,
    "bathrooms": r2_8
}

# Ordenar y mostrar las 3 mejores variables
top_3 = sorted(r2_values.items(), key=lambda x: x[1], reverse=True)[:3]
print("Las 3 variables con mayor correlación son:")
for variable, r2 in top_3:
    print(f"{variable}: R² = {r2:.4f}")
# Out:
# Las 3 variables con mayor correlación son:
# bathrooms: R² = 0.2971
# host_is_superhost: R² = 0.0802
# instant_bookable: R² = 0.0313
